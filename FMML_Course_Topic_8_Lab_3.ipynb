# %% [markdown]
# <a href="https://colab.research.google.com/github/LokeswariGottugundala/FMML_LAB_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-06 10:38:46--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   213MB/s    in 0.3s
#
# 2023-05-06 10:38:47 (213 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 32804  1507.05880v3  Supervised manifold learning methods learn dat...    cs
# 24373   1311.1279v1  We present an improved Locality Preserving Pro...    cs
# 18420   1006.0991v1  We introduce a framework for representing a va...    cs
# 6044   1606.04988v2  We create a new online reduction of multiclass...  stat
# 16338  1701.02946v1  Discourse parsing is an integral part of under...    cs
# ...             ...                                                ...   ...
# 22948  1711.07561v1  This is a technical report which explores the ...  stat
# 11782  1701.02133v1  Deep neural networks have been developed drawi...  stat
# 6190   1609.02631v1  This paper investigates the use of distributed...  stat
# 1020   1512.08806v3  We consider the statistical problem of learnin...  stat
# 27401  1703.05571v1  The Bag--of--Visual--Words (BoVW) is a visual ...    cs
#
#                                                    title  year  \
# 32804  A study of the classification of low-dimension...  2015
# 24373  Face Recognition via Globality-Locality Preser...  2013
# 18420                      Variational Program Inference  2010
# 6044                   Logarithmic Time One-Against-Some  2016
# 16338                Cross-lingual RST Discourse Parsing  2017
# ...                                                  ...   ...
# 22948             Review on Parameter Estimation in HMRF  2017
# 11782     Deep driven fMRI decoding of visual categories  2017
# 6190   Distributed Processing of Biosignal-Database f...  2016
# 1020   Common Variable Learning and Invariant Represe...  2015
# 27401  From visual words to a visual grammar: using l...  2017
#
#                                                 keywords
# 32804  [supervised, representations, preserving, geom...
# 24373  [preserving, projections, gloablity, preservin...
# 18420  [introduce, framework, representing, interesti...
# 6044   [reduction, multiclass, classification, classi...
# 16338  [discourse, understanding, information, argume...
# ...                                                  ...
# 22948  [technical, estimation, methodologies, paramet...
# 11782  [developed, inspiration, implementing, structu...
# 6190   [investigates, distributed, processing, recogn...
# 1020   [statistical, variability, synchronously, demo...
# 27401  [description, technique, shortening, partition...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 32804    [supervised, representations, preserving, geom...
# 24373    [preserving, projections, gloablity, preservin...
# 18420    [introduce, framework, representing, interesti...
# 6044     [reduction, multiclass, classification, classi...
# 16338    [discourse, understanding, information, argume...
#                                ...
# 23968    [processes, deglaciation, immediate, instituti...
# 16463    [approaches, automatic, recognition, significa...
# 27050    [convolutional, emergedseveral, extraction, ho...
# 12903    [concerned, computational, particular, computa...
# 20133    [researchers, satisficing, ameliorate, concert...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8784 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="327320e1-9861-4815-974a-8350d179b062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("327320e1-9861-4815-974a-8350d179b062")) {                    Plotly.newPlot(                        "327320e1-9861-4815-974a-8350d179b062",                        [{"x":["embeddings","supported","embedding","theoretical","interpolation","separation","algorithms","geometric","dimensionality","separability","generalization","exponential","representations","satisfying","condition","supervised","structure","satisfactory","dimensional","sufficiently","nonlinear","separable","necessary","experiments","enhancing","construction","different","classification","preserving","performance","reduction","extensive","constraint","recognition","considered","projections","conventional","techniques","respecting","formulate","experimental","demonstrate","structures","information","statistical","additional","significantly","objective","outperform","extension","databases","representing","divergence","inference","alongside","hypothesis","framework","variational","probabilistic","distribution","conditional","heuristic","estimated","represent","executions","importance","interesting","efficiently","posteriors","influences","probability","statistically","execution","posterior","introduce","algorithm","prediction","substantially","logarithmically","logarithmic","approaches","multiclass","improvements","translate","predictive","annotated","languages","linguistic","discourse","documents","portuguese","understanding","evaluating","underlying","competitive","argumentative","including","knowledge","illustrate","arithmetic","properties","conservative","stratified","usefulness","introduction","programming","aggregates","disjunctive","deficiency","furthermore","particular","computational","requiring","naturally","computation","decidable","implementation","functions","applications","expressing","complexity","expressed","expressive","especially","aggregate","efficiency","constructs","expressiveness","semantics","formalism","operators","conditions","relatively","specifically","presented","unsupervised","regularizers","reasonable","combination","particularly","classifying","devastating","regularization","designing","important","procedure","beneficial","achievable","convolutional","probabilities","predictors","efficient","empirically","calibration","theoretically","empirical","imprecise","automatically","guarantees","consistently","resulting","computationally","characterize","implement","sequential","iteratively","geological","strategies","derivation","metropolis","intensive","formalized","summarize","automatic","sophisticated","simulators","approximate","simulations","configurations","analytically","typically","inversion","sequentialized","simulator","formulation","difficult","parameters","inverting","insufficient","selective","accomplish","contributions","organizing","literature","multitude","perception","necessarily","artificial","perspectives","highlighting"],"y":[81,10,110,147,20,28,584,62,50,7,107,54,266,13,50,178,341,16,168,13,57,16,87,590,22,81,775,544,50,891,93,177,96,389,138,20,111,369,3,56,366,561,126,685,160,114,254,178,106,78,45,68,24,218,4,48,548,58,153,247,96,51,54,104,2,86,65,160,3,9,152,14,46,55,334,802,237,43,1,13,473,9,129,13,69,61,102,70,19,69,2,150,60,122,129,3,238,351,66,11,224,3,7,28,33,120,7,12,5,178,282,320,50,58,184,6,154,237,401,15,247,26,31,97,20,164,20,10,91,26,44,123,54,156,184,153,7,37,147,90,55,2,75,46,366,120,27,11,369,50,15,422,73,25,36,147,5,193,64,38,166,82,45,72,70,37,2,106,22,8,22,9,13,172,36,4,113,51,22,12,106,11,0,17,75,144,246,2,11,10,14,47,21,112,8,41,14,142,10,7],"type":"bar"},{"x":["embeddings","supported","embedding","theoretical","interpolation", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5);'>Discriminative</span> <span style=''>Phoneme</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>Sequences</span> <span style='background-color:rgba(0, 255, 0, 0.558282208588957);'>Extraction</span> <span style=''>for</span> <span style=''>Non</span> <span style=''>Native</span> <span style=''>Speakers</span> <span style=''>Origin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.41984732824427484);'>automated</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>origin</span> <span style=''>of</span> <span style=''>non</span> <span style=''>native</span> <span style=''>speakers</span> <span style=''>The</span> <span style=''>origin</span> <span style=''>of</span> <span style=''>non</span> <span style=''>native</span> <span style=''>speakers</span> <span style=''>could</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identified</span> <span style=''>by</span> <span style=''>a</span> <span style=''>human</span> <span style=''>listener</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5464362850971922);'>detection</span> <span style=''>of</span> <span style=''>typical</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>pronunciations</span> <span style=''>for</span> <span style=''>each</span> <span style=''>nationality</span> <span style=''>Thus</span> <span style=''>we</span> <span style=''>suppose</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>several</span> <span style=''>phoneme</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>sequences</span> <span style=''>that</span> <span style=''>might</span> <span style=''>allow</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>origin</span> <span style=''>of</span> <span style=''>non</span> <span style=''>native</span> <span style=''>speakers</span> <span style=''>Our</span> <span style=''>new</span> <span style=''>method</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.558282208588957);'>extraction</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>sequences</span> <span style=''>of</span> <span style=''>phonemes</span> <span style=''>from</span> <span style=''>a</span> <span style=''>non</span> <span style=''>native</span> <span style=''>English</span> <span style=''>speech</span> <span style=''>database</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>sequences</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style=''>the</span> <span style=''>speakers</span> <span style=''>origin</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Smoothing</span> <span style=''>Effects</span> <span style=''>of</span> <span style=''>Bagging</span> <span style=''>Von</span> <span style=''>Mises</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Expansions</span> <span style=''>of</span> <span style=''>Bagged</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functionals</span> <br/><br/><span style=''>Bagging</span> <span style=''>is</span> <span style=''>a</span> <span style=''>device</span> <span style=''>intended</span> <span style=''>for</span> <span style=''>reducing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>error</span> <span style=''>of</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style=''>its</span> <span style=''>simplest</span> <span style=''>form</span> <span style=''>bagging</span> <span style=''>draws</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style=''>training</span> <span style=''>sample</span> <span style=''>applies</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>sample</span> <span style=''>and</span> <span style=''>then</span> <span style=''>averages</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>rules</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>bagging</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functionals</span> <span style=''>and</span> <span style=''>study</span> <span style=''>the</span> <span style=''>von</span> <span style=''>Mises</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style=''>bagged</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functionals</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expansion</span> <span style=''>is</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Efron</span> <span style=''>Stein</span> <span style=''>ANOVA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>(unbagged)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>The</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>is</span> <span style=''>that</span> <span style=''>a</span> <span style=''>bagged</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>is</span> <span style=''>always</span> <span style=''>smooth</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>the</span> <span style=''>von</span> <span style=''>Mises</span> <span style='background-color:rgba( ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Near</span> <span style=''>optimal</span> <span style=''>Coresets</span> <span style=''>For</span> <span style=''>Least</span> <span style=''>Squares</span> <span style='background-color:rgba(255, 0, 0, 0.5541125541125542);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>(constrained)</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(255, 0, 0, 0.5541125541125542);'>regression</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>multiple</span> <span style=''>response</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(255, 0, 0, 0.5541125541125542);'>regression</span> <span style=''>and</span> <span style=''>ask</span> <span style=''>the</span> <span style=''>question</span> <span style=''>of</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>a</span> <span style=''>coreset</span> <span style=''>suffices</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5541125541125542);'>regression</span> <span style=''>We</span> <span style=''>give</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>low</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>such</span> <span style=''>coresets</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(255, 0, 0, 0.3005464480874317);'>guarantees</span> <span style=''>together</span> <span style=''>with</span> <span style=''>lower</span> <span style=''>bounds</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>indicating</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style=''>not</span> <span style=''>much</span> <span style=''>room</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3660714285714286);'>improvement</span> <span style=''>upon</span> <span style=''>our</span> <span style=''>results</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complementary</span> <span style=''>Labels</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Collecting</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>is</span> <span style=''>costly</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>a</span> <span style=''>critical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bottleneck</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>To</span> <span style=''>mitigate</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>setting</span> <span style=''>namely</span> <span style=''>learning</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complementary</span> <span style=''>labels</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complementary</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifies</span> <span style=''>a</span> <span style=''>class</span> <span style=''>that</span> <span style=''>a</span> <span style=''>pattern</span> <span style=''>does</span> <span style=''>not</span> <span style=''>belong</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Collecting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complementary</span> <span style=''>labels</span> <span style=''>would</span> <span style=''>be</span> <span style=''>less</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>laborious</span> <span style=''>than</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collecting</span> <span style=''>ordinary</span> <span style=''>labels</span> <span style=''>since</span> <span style=''>users</span> <span style=''>do</span> <span style=''>not</span> <span style=''>have</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style=''>choose</span> <span style=''>the</span> <span style=''>correct</span> <span style=''>class</span> <span style=''>from</span> <span style=''>a</span> <span style=''>long</span> <span style=''>list</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>classes</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complementary</span> <span style=''>labels</span> <span style=''>are</span> <span style=''>less</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style=''>than</span> <span style=''>ordinary</span> <span style=''>labels</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>better</span> <span style=''>learn</span> <span style=''>from</span> <span style=''>them</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>an</span> <span style=''>unbiased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>risk</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06467840459935321)
# 	processing (0.10384477182896155)
# 	knowledge (0.12612288896873877)
# 	representation (0.13510600071864895)
# 	architecture (0.09198706431908013)
# 	information (0.24613726194753863)
# 	detection (0.1286381602587136)
# 	different (0.2784764642472152)
# 	convolutional (0.1325907294286741)
# 	recognition (0.13977721882860222)
#
# Some Statistics words are:
# 	stochastic (0.12989588497768964)
# 	variables (0.13584531482399603)
# 	algorithm (0.37977193852255825)
# 	estimation (0.17104610808130888)
# 	statistical (0.15518096182449181)
# 	distribution (0.18740704015865145)
# 	theoretical (0.15270203272186417)
# 	inference (0.20079325731284084)
# 	dimensional (0.18443232523549827)
# 	regression (0.17798710956866634)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3984a9fa-dcf5-4928-abb6-2d4b339b6ab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3984a9fa-dcf5-4928-abb6-2d4b339b6ab5")) {                    Plotly.newPlot(                        "3984a9fa-dcf5-4928-abb6-2d4b339b6ab5",                        [{"x":["embeddings","supported","embedding","theoretical","interpolation","separation","algorithms","geometric","dimensionality","separability","generalization","exponential","representations","satisfying","condition","supervised","structure","satisfactory","dimensional","sufficiently","nonlinear","separable","necessary","experiments","enhancing","construction","different","classification","preserving","performance","reduction","extensive","constraint","recognition","considered","projections","conventional","techniques","respecting","formulate","experimental","demonstrate","structures","information","statistical","additional","significantly","objective","outperform","extension","databases","representing","divergence","inference","alongside","hypothesis","framework","variational","probabilistic","distribution","conditional","heuristic","estimated","represent","executions","importance","interesting","efficiently","posteriors","influences","probability","statistically","execution","posterior","introduce","algorithm","prediction","substantially","logarithmically","logarithmic","approaches","multiclass","improvements","translate","predictive","annotated","languages","linguistic","discourse","documents","portuguese","understanding","evaluating","underlying","competitive","argumentative","including","knowledge","illustrate","arithmetic","properties","conservative","stratified","usefulness","introduction","programming","aggregates","disjunctive","deficiency","furthermore","particular","computational","requiring","naturally","computation","decidable","implementation","functions","applications","expressing","complexity","expressed","expressive","especially","aggregate","efficiency","constructs","expressiveness","semantics","formalism","operators","conditions","relatively","specifically","presented","unsupervised","regularizers","reasonable","combination","particularly","classifying","devastating","regularization","designing","important","procedure","beneficial","achievable","convolutional","probabilities","predictors","efficient","empirically","calibration","theoretically","empirical","imprecise","automatically","guarantees","consistently","resulting","computationally","characterize","implement","sequential","iteratively","geological","strategies","derivation","metropolis","intensive","formalized","summarize","automatic","sophisticated","simulators","approximate","simulations","configurations","analytically","typically","inversion","sequentialized","simulator","formulation","difficult","parameters","inverting","insufficient","selective","accomplish","contributions","organizing","literature","multitude","perception","necessarily","artificial","perspectives","highlighting","revisiting","intelligence","successes","simulation","critically","recovered","stochastic","represents","coefficients","robustness","appropriate","blockmodels","representation","adjacency","dimension","distributed","classifier","effectiveness","according","consistency","asymptotically","resolution","validation","distillation","preliminary","binarized","following","published","discussion","googlenet","application","meaningful","containing","unexpected","behavioral","translating","quantitative","instances","variations","stretching","analyzing","situation","monitoring","qualitative","installed","challenging","researchers","deviation","provision","multivariate","heterogeneous","alternate","viewpoint","differentiable","supervision","predi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sequentialized
# 	misspecified
# 	psychiatric
# 	convexification
# 	homogeneity
# 	semiparametric
# 	frontiers
# 	functionals
# 	sparsistent
# 	replicable
# 	detectability
# 	datastreams
# 	heartbeats
# 	interchangeable
# 	emphstatistical
# 	hippocampal
# 	hippocampus
# 	diameters
# 	integrals
# 	reparameterized
# Some words which never appear in Statistics papers:
# 	executions
# 	discourse
# 	portuguese
# 	argumentative
# 	disjunctive
# 	decidable
# 	devastating
# 	installed
# 	monocular
# 	apertures
# 	spectrally
# 	radiologists
# 	mammography
# 	contradictory
# 	surpassed
# 	mammograms
# 	mammogram
# 	photometric
# 	coordination
# 	conversational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.086610284585468e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7475
